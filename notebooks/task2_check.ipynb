# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_encoded_95 = pd.read_csv("../data/encoded_dataset/encoded_partial_df.csv")
df_5 = pd.read_csv("../data/streaming_dataset/to_be_encoded.csv")

# %%
df_encoded_95.head(2)
# Out:
#    transaction_id   timestamp  customer_id  stock_ticker  quantity  \
# 0               1  2023-01-02         4747             1        15
# 1               2  2023-01-02         4747             3        68
#
#    average_trade_size  day_name  is_weekend  is_holiday stock_liquidity_tier  \
# 0            2.708050         0           0           0                  Low
# 1            3.725693         0           0           0                  Low
#
#    ...  stock_sector_Healthcare  stock_sector_Technology  \
# 0  ...                    False                    False
# 1  ...                    False                    False
#
#    stock_industry_Asset Management  stock_industry_Hardware  \
# 0                            False                    False
# 1                             True                    False
#
#    stock_industry_Oil & Gas  stock_industry_Pharmaceuticals  \
# 0                     False                           False
# ...

# %%
len(df_encoded_95.columns)
# Out:
# 29

# %%
len(df_5.columns)
# Out:
# 16

# %%
df_5[df_5["transaction_id"] == 3858]
# Out:
#     transaction_id   timestamp  customer_id stock_ticker transaction_type  \
# 83            3858  2023-10-06            4       STK008              BUY
#
#     quantity  average_trade_size customer_account_type day_name  is_weekend  \
# 83       417            5.495528                Retail   Friday       False
#
#     is_holiday stock_liquidity_tier stock_sector stock_industry  stock_price  \
# 83       False                 High       Energy      Oil & Gas   126.658642
#
#     total_trade_amount
# 83        52816.653801

# %%
df_5.head(2)
# Out:
#    transaction_id   timestamp  customer_id stock_ticker transaction_type  \
# 0            6253  2024-03-14         1006       STK006              BUY
# 1            4685  2023-12-04         4955       STK006             SELL
#
#    quantity  average_trade_size customer_account_type  day_name  is_weekend  \
# 0       477            5.820083                Retail  Thursday       False
# 1       137            5.336528                Retail    Monday       False
#
#    is_holiday stock_liquidity_tier stock_sector stock_industry  stock_price  \
# 0       False                 High       Energy      Oil & Gas    71.652430
# 1       False                 High       Energy      Oil & Gas    94.439581
#
#    total_trade_amount
# 0        34178.209019
# 1        12938.222656

# %%
df_5[df_5["is_holiday"] == True]
# Out:
#      transaction_id   timestamp  customer_id stock_ticker transaction_type  \
# 9               440  2023-01-30          182       STK009              BUY
# 53             8128  2024-07-29         1903       STK006              BUY
# 86             3306  2023-08-29         3588       STK006             SELL
# 253            6600  2024-04-08         3933       STK009              BUY
# 301            1409  2023-04-11         3853       STK012              BUY
# 307            6604  2024-04-08          653       STK012              BUY
# 313            6596  2024-04-08         4955       STK006              BUY
# 344            8135  2024-07-29         1270       STK009              BUY
# 383            3313  2023-08-29         2409       STK009              BUY
# 411            4368  2023-11-13         4747       STK009              BUY
# 424            9644  2024-11-13         4747       STK019              BUY
#
# ...
